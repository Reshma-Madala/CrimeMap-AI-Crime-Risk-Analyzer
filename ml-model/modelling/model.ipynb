# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
from pymongo import MongoClient

# MongoDB connection
client = MongoClient("mongodb+srv://reshma_madala:admin123@crimewatch.ntwx0xx.mongodb.net/")
db = client["crimesdata"]
collection = db["crimestable"]

# Load data from MongoDB
data = pd.DataFrame(list(collection.find()))
print(f"Loaded {len(data)} records")

# Drop MongoDB's default _id column
data.drop(columns=["_id"], inplace=True)
data.head()
# Out:
# Loaded 40160 records
#    Report Number        Date Reported   Date of Occurrence  \
# 0              1  2020-01-02 00:00:00  2020-01-01 00:00:00
# 1              2  2020-01-01 19:00:00  2020-01-01 01:00:00
# 2              3  2020-01-02 05:00:00  2020-01-01 02:00:00
# 3              4  2020-01-01 05:00:00  2020-01-01 03:00:00
# 4              5  2020-01-01 21:00:00  2020-01-01 04:00:00
#
#    Time of Occurrence  Crime Code Crime Description  Victim Age   Weapon Used  \
# 0                 1.0         576    IDENTITY THEFT          16  Blunt Object
# 1                 6.0         128          HOMICIDE          37        Poison
# 2                14.0         271        KIDNAPPING          48  Blunt Object
# 3                14.0         170          BURGLARY          49       Firearm
# 4                16.0         421         VANDALISM          30         Other
#
#    Police Deployed Case Closed  ... City_Vasai  City_Visakhapatnam  \
# 0               13          No  ...      False               False
# 1                9          No  ...      False               False
# 2               15          No  ...      False               False
# 3                1         Yes  ...      False               False
# 4               18         Yes  ...      False               False
#
#    Crime Domain_Other Crime  Crime Domain_Traffic Fatality  \
# 0                     False                          False
# 1                      True                          False
# 2                      True                          False
# 3                      True                          False
# 4                      True                          False
#
#    Crime Domain_Violent Crime  Victim Gender_M  Victim Gender_X  Hour of Day  \
# 0                        True             True            False            1
# 1                       False             True            False            6
# 2                       False            False            False           14
# 3                       False            False            False           14
# 4                       False            False            False           16
#
#    Day of Week  Month
# 0          2.0    1.0
# 1          2.0    1.0
# 2          2.0    1.0
# 3          2.0    1.0
# 4          2.0    1.0
#
# [5 rows x 47 columns]

# %%
data.info()
data.describe(include='all')
data.isnull().sum().sort_values(ascending=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40160 entries, 0 to 40159
# Data columns (total 47 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Report Number                  40160 non-null  int64
#  1   Date Reported                  40160 non-null  object
#  2   Date of Occurrence             15840 non-null  object
#  3   Time of Occurrence             40160 non-null  float64
#  4   Crime Code                     40160 non-null  int64
#  5   Crime Description              40160 non-null  object
#  6   Victim Age                     40160 non-null  int64
#  7   Weapon Used                    40160 non-null  object
#  8   Police Deployed                40160 non-null  int64
#  9   Case Closed                    40160 non-null  object
#  10  Date Case Closed               40160 non-null  object
#  11  City_Ahmedabad                 40160 non-null  bool
#  12  City_Bangalore                 40160 non-null  bool
#  13  City_Bhopal                    40160 non-null  bool
#  14  City_Chennai                   40160 non-null  bool
#  15  City_Delhi                     40160 non-null  bool
#  16  City_Faridabad                 40160 non-null  bool
#  17  City_Ghaziabad                 40160 non-null  bool
#  18  City_Hyderabad                 40160 non-null  bool
#  19  City_Indore                    40160 non-null  bool
#  20  City_Jaipur                    40160 non-null  bool
#  21  City_Kalyan                    40160 non-null  bool
#  22  City_Kanpur                    40160 non-null  bool
#  23  City_Kolkata                   40160 non-null  bool
#  24  City_Lucknow                   40160 non-null  bool
#  25  City_Ludhiana                  40160 non-null  bool
#  26  City_Meerut                    40160 non-null  bool
#  27  City_Mumbai                    40160 non-null  bool
#  28  City_Nagpur                    40160 non-null  bool
#  29  City_Nashik                    40160 non-null  bool
#  30  City_Patna                     40160 non-null  bool
#  31  City_Pune                      40160 non-null  bool
#  32  City_Rajkot                    40160 non-null  bool
#  33  City_Srinagar                  40160 non-null  bool
#  34  City_Surat                     40160 non-null  bool
#  35  City_Thane                     40160 non-null  bool
#  36  City_Varanasi                  40160 non-null  bool
#  37  City_Vasai                     40160 non-null  bool
#  38  City_Visakhapatnam             40160 non-null  bool
#  39  Crime Domain_Other Crime       40160 non-null  bool
#  40  Crime Domain_Traffic Fatality  40160 non-null  bool
#  41  Crime Domain_Violent Crime     40160 non-null  bool
#  42  Victim Gender_M                40160 non-null  bool
#  43  Victim Gender_X                40160 non-null  bool
#  44  Hour of Day                    40160 non-null  int64
#  45  Day of Week                    15840 non-null  float64
#  46  Month                          15840 non-null  float64
# dtypes: bool(33), float64(3), int64(5), object(6)
# memory usage: 5.6+ MB
# Month                            24320
# Date of Occurrence               24320
# Day of Week                      24320
# City_Thane                           0
# City_Meerut                          0
# City_Mumbai                          0
# City_Nagpur                          0
# City_Nashik                          0
# City_Patna                           0
# City_Pune                            0
# City_Rajkot                          0
# City_Srinagar                        0
# City_Surat                           0
# City_Varanasi                        0
# City_Lucknow                         0
# City_Vasai                           0
# City_Visakhapatnam                   0
# Crime Domain_Other Crime             0
# Crime Domain_Traffic Fatality        0
# Crime Domain_Violent Crime           0
# Victim Gender_M                      0
# Victim Gender_X                      0
# Hour of Day                          0
# City_Ludhiana                        0
# Report Number                        0
# Date Reported                        0
# City_Kanpur                          0
# Time of Occurrence                   0
# Crime Code                           0
# Crime Description                    0
# Victim Age                           0
# Weapon Used                          0
# Police Deployed                      0
# Case Closed                          0
# Date Case Closed                     0
# City_Ahmedabad                       0
# City_Bangalore                       0
# City_Bhopal                          0
# City_Chennai                         0
# City_Delhi                           0
# City_Faridabad                       0
# City_Ghaziabad                       0
# City_Hyderabad                       0
# City_Indore                          0
# City_Jaipur                          0
# City_Kalyan                          0
# City_Kolkata                         0
# dtype: int64

# %%
# Handle missing values (Fill missing values for "Day of Week", "Month", "Date of Occurrence")
data["Day of Week"].fillna(data["Day of Week"].mode()[0], inplace=True)
data["Month"].fillna(data["Month"].mode()[0], inplace=True)
data["Date of Occurrence"].fillna(method='ffill', inplace=True)  # Fill forward for missing date
# Out:
# C:\Users\mvr29\AppData\Local\Temp\ipykernel_4956\1729878238.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data["Date of Occurrence"].fillna(method='ffill', inplace=True)  # Fill forward for missing date

# %%
# Feature Engineering: Extract useful features from 'Date of Occurrence'
data['Date of Occurrence'] = pd.to_datetime(data['Date of Occurrence'])
data['Hour of Day'] = data['Date of Occurrence'].dt.hour
data['Day of Week'] = data['Date of Occurrence'].dt.dayofweek
data['Month'] = data['Date of Occurrence'].dt.month

# %%
# Age Group Binning
data['Age Group'] = pd.cut(data['Victim Age'], bins=[0, 12, 18, 65, 100], labels=['Child', 'Teen', 'Adult', 'Senior'])

# %%
# Encoding Categorical Features
label_encoder = LabelEncoder()
data['Crime_Description_Code'] = label_encoder.fit_transform(data['Crime Description'])
data['Weapon_Code'] = label_encoder.fit_transform(data['Weapon Used'])

# %%
# One-Hot Encoding for 'City_*' and other categorical columns
city_columns = [col for col in data.columns if 'City_' in col]
data = pd.get_dummies(data, columns=city_columns, drop_first=True)

# %%
# Drop columns that aren't necessary for prediction
data.drop(columns=['Report Number', 'Date Reported', 'Date Case Closed', 'Case Closed', 'Crime Domain_Other Crime', 'Crime Domain_Traffic Fatality'], inplace=True)

# %%
# Select Features (X) and Target (y)
X = data.drop(columns=['Crime_Description_Code', 'Age Group'])
y_crime_type = data['Crime_Description_Code']  # Target for crime type prediction
y_age_group = data['Age Group']  # Target for victim age group prediction

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y_crime_type, test_size=0.2, random_state=42)

# %%
# Apply SMOTE to handle imbalanced data
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Apply SMOTE to handle imbalanced data
#       2 smote = SMOTE(random_state=42)
# ----> 3 X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)
#
# File c:\Users\mvr29\AppData\Local\Programs\Python\Python312\Lib\site-packages\imblearn\base.py:208, in BaseSampler.fit_resample(self, X, y)
#     187 """Resample the dataset.
#     188
#     189 Parameters
#    (...)
#     205     The corresponding label of `X_resampled`.
#     206 """
#     207 self._validate_params()
# --> 208 return super().fit_resample(X, y)
#
# File c:\Users\mvr29\AppData\Local\Programs\Python\Python312\Lib\site-packages\imblearn\base.py:106, in SamplerMixin.fit_resample(self, X, y)
#     104 check_classification_targets(y)
#     105 arrays_transformer = ArraysTransformer(X, y)
# --> 106 X, y, binarize_y = self._check_X_y(X, y)
#     108 self.sampling_strategy_ = check_sampling_strategy(
#     109     self.sampling_strategy, y, self._sampling_type
#     110 )
#     112 output = self._fit_resample(X, y)
#
# File c:\Users\mvr29\AppData\Local\Programs\Python\Python312\Lib\site-packages\imblearn\base.py:161, in BaseSampler._check_X_y(self, X, y, accept_sparse)
#     159     accept_sparse = ["csr", "csc"]
#     160 y, binarize_y = check_target_type(y, indicate_one_vs_all=True)
# --> 161 X, y = self._validate_data(X, y, reset=True, accept_sparse=accept_sparse)
#     162 return X, y, binarize_y
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:622, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     620         y = check_array(y, input_name="y", **check_y_params)
#     621     else:
# --> 622         X, y = check_X_y(X, y, **check_params)
#     623     out = X, y
#     625 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:1146, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1141         estimator_name = _check_estimator_name(estimator)
#    1142     raise ValueError(
#    1143         f"{estimator_name} requires y to be passed, but the target y is None"
#    1144     )
# -> 1146 X = check_array(
#    1147     X,
#    1148     accept_sparse=accept_sparse,
#    1149     accept_large_sparse=accept_large_sparse,
#    1150     dtype=dtype,
#    1151     order=order,
#    1152     copy=copy,
#    1153     force_all_finite=force_all_finite,
#    1154     ensure_2d=ensure_2d,
#    1155     allow_nd=allow_nd,
#    1156     ensure_min_samples=ensure_min_samples,
#    1157     ensure_min_features=ensure_min_features,
#    1158     estimator=estimator,
#    1159     input_name="X",
#    1160 )
#    1162 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1164 check_consistent_length(X, y)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:836, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     831 if pandas_requires_conversion:
#     832     # pandas dataframe requires conversion earlier to handle extension dtypes with
#     833     # nans
#     834     # Use the original dtype for conversion if dtype is None
#     835     new_dtype = dtype_orig if dtype is None else dtype
# --> 836     array = array.astype(new_dtype)
#     837     # Since we converted here, we do not need to convert again later
#     838     dtype = None
#
# File c:\Users\mvr29\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File c:\Users\mvr29\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File c:\Users\mvr29\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\mvr29\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File c:\Users\mvr29\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File c:\Users\mvr29\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:180, in astype_array(values, dtype, copy)
#     176     return values
#     178 if not isinstance(values, np.ndarray):
#     179     # i.e. ExtensionArray
# --> 180     values = values.astype(dtype, copy=copy)
#     182 else:
#     183     values = _astype_nansafe(values, dtype, copy=copy)
#
# File c:\Users\mvr29\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arrays\datetimes.py:727, in DatetimeArray.astype(self, dtype, copy)
#     725 elif isinstance(dtype, PeriodDtype):
#     726     return self.to_period(freq=dtype.freq)
# --> 727 return dtl.DatetimeLikeArrayMixin.astype(self, dtype, copy)
#
# File c:\Users\mvr29\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arrays\datetimelike.py:489, in DatetimeLikeArrayMixin.astype(self, dtype, copy)
#     485 elif (dtype.kind in "mM" and self.dtype != dtype) or dtype.kind == "f":
#     486     # disallow conversion between datetime/timedelta,
#     487     # and conversions for any datetimelike to float
#     488     msg = f"Cannot cast {type(self).__name__} to dtype {dtype}"
# --> 489     raise TypeError(msg)
#     490 else:
#     491     return np.asarray(self, dtype=dtype)
#
# TypeError: Cannot cast DatetimeArray to dtype float64
